# %%
import pandas as pd

df = pd.read_csv('tournaments.csv')
df2 = pd.read_csv('updated_tournaments.csv')

# %%
teams = pd.read_csv('teams.csv')

teams
# Out:
#     key_id team_id      team_name team_code  \
# 0        1    T-01        Algeria       DZA
# 1        2    T-02         Angola       AGO
# 2        3    T-03      Argentina       ARG
# 3        4    T-04      Australia       AUS
# 4        5    T-05        Austria       AUT
# ..     ...     ...            ...       ...
# 76      79    T-79  United States       USA
# 77      80    T-80        Uruguay       URY
# 78      81    T-81          Wales       WAL
# 79      83    T-83     Yugoslavia       YUG
# 80      84    T-84          Zaire       COD
#
#                               federation_name    region_name confederation_id  \
# 0                Algerian Football Federation         Africa             CF-2
# 1                 Angolan Football Federation         Africa             CF-2
# 2              Argentine Football Association  South America             CF-4
# 3                          Football Australia        Oceania             CF-1
# ...

# %%
df
# Out:
#     key_id tournament_id      tournament_name  year  start_date    end_date  \
# 0        1       WC-1930  1930 FIFA World Cup  1930  1930-07-13  1930-07-30
# 1        2       WC-1934  1934 FIFA World Cup  1934  1934-05-27  1934-06-10
# 2        3       WC-1938  1938 FIFA World Cup  1938  1938-06-04  1938-06-19
# 3        4       WC-1950  1950 FIFA World Cup  1950  1950-06-24  1950-07-16
# 4        5       WC-1954  1954 FIFA World Cup  1954  1954-06-16  1954-07-04
# 5        6       WC-1958  1958 FIFA World Cup  1958  1958-06-08  1958-06-29
# 6        7       WC-1962  1962 FIFA World Cup  1962  1962-05-30  1962-07-17
# 7        8       WC-1966  1966 FIFA World Cup  1966  1966-07-11  1966-07-30
# 8        9       WC-1970  1970 FIFA World Cup  1970  1970-05-31  1970-06-21
# 9       10       WC-1974  1974 FIFA World Cup  1974  1974-06-13  1974-07-07
# 10      11       WC-1978  1978 FIFA World Cup  1978  1978-06-01  1978-06-25
# ...

# %%
df2
# Out:
#     key_id tournament_id      tournament_name  year  start_date    end_date  \
# 0        1       WC-1930  1930 FIFA World Cup  1930  1930-07-13  1930-07-30
# 1        2       WC-1934  1934 FIFA World Cup  1934  1934-05-27  1934-06-10
# 2        3       WC-1938  1938 FIFA World Cup  1938  1938-06-04  1938-06-19
# 3        4       WC-1950  1950 FIFA World Cup  1950  1950-06-24  1950-07-16
# 4        5       WC-1954  1954 FIFA World Cup  1954  1954-06-16  1954-07-04
# 5        6       WC-1958  1958 FIFA World Cup  1958  1958-06-08  1958-06-29
# 6        7       WC-1962  1962 FIFA World Cup  1962  1962-05-30  1962-07-17
# 7        8       WC-1966  1966 FIFA World Cup  1966  1966-07-11  1966-07-30
# 8        9       WC-1970  1970 FIFA World Cup  1970  1970-05-31  1970-06-21
# 9       10       WC-1974  1974 FIFA World Cup  1974  1974-06-13  1974-07-07
# 10      11       WC-1978  1978 FIFA World Cup  1978  1978-06-01  1978-06-25
# ...

# %%
teams = pd.read_csv('updated_teams.csv')

# %%
teams
# Out:
#     key_id team_id           team_name team_code  \
# 0        1    T-01       Susan Jackson       DZA
# 1        2    T-02       Charles Lopez       AGO
# 2        3    T-03    Richard Martinez       ARG
# 3        4    T-04       Charles Moore       AUS
# 4        5    T-05    Barbara Gonzalez       AUT
# ..     ...     ...                 ...       ...
# 76      79    T-79       James Johnson       USA
# 77      80    T-80      James Martinez       URY
# 78      81    T-81  Elizabeth Anderson       WAL
# 79      83    T-83      Barbara Martin       YUG
# 80      84    T-84      Patricia Davis       COD
#
#                               federation_name    region_name confederation_id  \
# 0                Algerian Football Federation         Africa             CF-2
# 1                 Angolan Football Federation         Africa             CF-2
# 2              Argentine Football Association  South America             CF-4
# ...

# %%
team_stats = pd.read_csv('Updated_teams_overall_stats.csv')
team_stats
# Out:
#              team_name  winning_times  count_matches  participations  \
# 0     Richard Martinez              2             81              17
# 1    Michael Hernandez              5            109              21
# 2   Elizabeth Williams              1             69              15
# 3         John Jackson              2             66              15
# 4       Patricia Davis              4            115              20
# ..                 ...            ...            ...             ...
# 77      Karen Gonzalez              0              3               1
# 78       James Johnson              0             33              10
# 79  Elizabeth Anderson              0              5               1
# 80      Barbara Martin              0             37               9
# 81      Patricia Davis              0              3               1
#
#     win_counts  lose_counts  draws  scored  received  yellow_cards  red_cards
# ...

# %%
qualified_teams = pd.read_csv('qualified_teams.csv')
qualified_teams
# Out:
#      key_id tournament_id      tournament_name team_id    team_name team_code  \
# 0         1       WC-1930  1930 FIFA World Cup    T-03    Argentina       ARG
# 1         2       WC-1930  1930 FIFA World Cup    T-06      Belgium       BEL
# 2         3       WC-1930  1930 FIFA World Cup    T-07      Bolivia       BOL
# 3         4       WC-1930  1930 FIFA World Cup    T-09       Brazil       BRA
# 4         5       WC-1930  1930 FIFA World Cup    T-13        Chile       CHL
# ..      ...           ...                  ...     ...          ...       ...
# 452     453       WC-2018  2018 FIFA World Cup    T-70        Spain       ESP
# 453     454       WC-2018  2018 FIFA World Cup    T-71       Sweden       SWE
# 454     455       WC-2018  2018 FIFA World Cup    T-72  Switzerland       CHE
# 455     456       WC-2018  2018 FIFA World Cup    T-75      Tunisia       TUN
# 456     457       WC-2018  2018 FIFA World Cup    T-80      Uruguay       URY
#
# ...

# %%
bookings = pd.read_csv('bookings.csv')
bookings
# Out:
#       key_id booking_id tournament_id      tournament_name   match_id  \
# 0          1     B-0001       WC-1970  1970 FIFA World Cup  M-1970-01
# 1          2     B-0002       WC-1970  1970 FIFA World Cup  M-1970-01
# 2          3     B-0003       WC-1970  1970 FIFA World Cup  M-1970-01
# 3          4     B-0004       WC-1970  1970 FIFA World Cup  M-1970-01
# 4          5     B-0005       WC-1970  1970 FIFA World Cup  M-1970-01
# ...      ...        ...           ...                  ...        ...
# 2461    2462     B-2462       WC-2018  2018 FIFA World Cup  M-2018-63
# 2462    2463     B-2463       WC-2018  2018 FIFA World Cup  M-2018-63
# 2463    2464     B-2464       WC-2018  2018 FIFA World Cup  M-2018-64
# 2464    2465     B-2465       WC-2018  2018 FIFA World Cup  M-2018-64
# 2465    2466     B-2466       WC-2018  2018 FIFA World Cup  M-2018-64
#
#                  match_name  match_date         stage_name      group_name  \
# ...
